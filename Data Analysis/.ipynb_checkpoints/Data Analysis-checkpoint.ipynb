# %% [markdown]
# CS315 Group 2 Project 3

# %%
import os, types
import re
import csv
from pandas import Series, DataFrame
import pandas as pd
import dateutil.parser as dparser
from random import randint
from collections import Counter

# %%
data = pd.read_csv("results_38129.csv")
posts = pd.DataFrame(data)
posts = posts[posts['video_description'].notna()]
posts = posts[posts['video_locationcreated'] == 'US']
posts.head()
# Out:
#               video_id      video_timestamp  video_duration  \
# 2  7322961317084663082  2024-01-11T16:50:11            70.0
# 5  7327002161089400106  2024-01-22T14:11:10            13.0
# 6  7320741405444312362  2024-01-05T17:15:53            15.0
# 8  7311859359896620331  2023-12-12T18:48:48            16.0
# 9  7312572200668794158  2023-12-14T16:55:02            15.0
#
#   video_locationcreated                                    suggested_words  \
# 2                    US  jayllnn, buldak ramen noodles, noodles, realja...
# 5                    US  stop recording me, stop attacking me, stop rec...
# 6                    US  chel cosplay, Chel The Road To El Dorado, Chel...
# 8                    US  cfn cabbage, Laffy Taffy, cfn kasai, bigcabbag...
# 9                    US  Zoe Ebarb Throwing It, zoe ebarb, Mulheres Dan...
#
#    video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 2         698300.0            6955.0              6421.0       20100000.0
# 5        3800000.0           79000.0             20400.0       25600000.0
# 6         428500.0            3998.0              3559.0        2600000.0
# 8         971800.0           10600.0              4268.0        5300000.0
# 9         129000.0             768.0               696.0         699900.0
#
#                                    video_description  video_is_ad  \
# 2                                          #noodles         False
# 5  If Grama Sandy comes up to you in a store and ...        False
# 6  Im hearing everyone out || @Rat || ac mp3 serv...        False
# 8  Im just trying to see if my  face clean😂 #fyp ...        False
# 9                              Dc @emiliexpirez !!!!        False
#
#    video_stickers author_username  author_name  author_followercount  \
# 2             NaN     realjayllnn      JAYLLNN                   NaN
# 5             NaN   sandybepsycho  Grama Sandy                   NaN
# 6             NaN         quizkai       Wuizzy                   NaN
# 8             NaN    bigcabbage56  CFN Cabbage                   NaN
# 9             NaN       zoe.ebarb         Zoe🐸                   NaN
#
#    author_followingcount  author_heartcount  author_videocount  \
# 2                    NaN                NaN                NaN
# 5                    NaN                NaN                NaN
# 6                    NaN                NaN                NaN
# 8                    NaN                NaN                NaN
# 9                    NaN                NaN                NaN
#
#    author_diggcount  author_verified
# 2               NaN             True
# 5               NaN            False
# 6               NaN            False
# 8               NaN            False
# 9               NaN            False

# %%
def getHashtags(text):
  """Takes a string phrase and returns hashtags if present"""
  if isinstance(text, str):
    return re.findall(r"#(\S+)", text.lower())
  return []

# %%
#extracts the hashtags for each post
posts['hashtags'] = posts['video_description'].apply(getHashtags)
#remove posts with no hashtags
posts = posts[posts['hashtags'].map(lambda x: len(x)) > 0]
posts.head()
# Out:
#                video_id      video_timestamp  video_duration  \
# 2   7322961317084663082  2024-01-11T16:50:11            70.0
# 5   7327002161089400106  2024-01-22T14:11:10            13.0
# 6   7320741405444312362  2024-01-05T17:15:53            15.0
# 8   7311859359896620331  2023-12-12T18:48:48            16.0
# 10  7315878397568191787  2023-12-23T14:44:48            26.0
#
#    video_locationcreated                                    suggested_words  \
# 2                     US  jayllnn, buldak ramen noodles, noodles, realja...
# 5                     US  stop recording me, stop attacking me, stop rec...
# 6                     US  chel cosplay, Chel The Road To El Dorado, Chel...
# 8                     US  cfn cabbage, Laffy Taffy, cfn kasai, bigcabbag...
# 10                    US  lucid dreams, i still see your shadows, Hey Th...
#
#     video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 2          698300.0            6955.0              6421.0       20100000.0
# 5         3800000.0           79000.0             20400.0       25600000.0
# 6          428500.0            3998.0              3559.0        2600000.0
# 8          971800.0           10600.0              4268.0        5300000.0
# 10        4100000.0           77500.0             20000.0       29600000.0
#
#                                     video_description  ...  video_stickers  \
# 2                                           #noodles   ...             NaN
# 5   If Grama Sandy comes up to you in a store and ...  ...             NaN
# 6   Im hearing everyone out || @Rat || ac mp3 serv...  ...             NaN
# 8   Im just trying to see if my  face clean😂 #fyp ...  ...             NaN
# 10  shoutout my lil bro 🙎🏻‍♂️ for recording this i...  ...             NaN
#
#     author_username  author_name author_followercount  author_followingcount  \
# 2       realjayllnn      JAYLLNN                  NaN                    NaN
# 5     sandybepsycho  Grama Sandy                  NaN                    NaN
# 6           quizkai       Wuizzy                  NaN                    NaN
# 8      bigcabbage56  CFN Cabbage                  NaN                    NaN
# 10          whyk4re        ykare                  NaN                    NaN
#
#     author_heartcount  author_videocount  author_diggcount  author_verified  \
# 2                 NaN                NaN               NaN             True
# 5                 NaN                NaN               NaN            False
# 6                 NaN                NaN               NaN            False
# 8                 NaN                NaN               NaN            False
# 10                NaN                NaN               NaN            False
#
#                                              hashtags
# 2                                           [noodles]
# 5   [fyp, sandybepsycho, recordme, strangers, vira...
# 6   [theroadtoeldorado, chel, pixar, disney, chele...
# 8            [fyp, xybca, cfn, mammoo, thatoneperson]
# 10               [juicewrld, luciddreams, fypシ゚viral]
#
# [5 rows x 21 columns]

# %%
#a smaller dataframe with just the needed functions
posts2 = posts[["video_id", "author_username", "video_description",
                "hashtags", "suggested_words"]].copy()
posts2.head()
# Out:
#                video_id author_username  \
# 2   7322961317084663082     realjayllnn
# 5   7327002161089400106   sandybepsycho
# 6   7320741405444312362         quizkai
# 8   7311859359896620331    bigcabbage56
# 10  7315878397568191787         whyk4re
#
#                                     video_description  \
# 2                                           #noodles
# 5   If Grama Sandy comes up to you in a store and ...
# 6   Im hearing everyone out || @Rat || ac mp3 serv...
# 8   Im just trying to see if my  face clean😂 #fyp ...
# 10  shoutout my lil bro 🙎🏻‍♂️ for recording this i...
#
#                                              hashtags  \
# 2                                           [noodles]
# 5   [fyp, sandybepsycho, recordme, strangers, vira...
# 6   [theroadtoeldorado, chel, pixar, disney, chele...
# 8            [fyp, xybca, cfn, mammoo, thatoneperson]
# 10               [juicewrld, luciddreams, fypシ゚viral]
#
#                                       suggested_words
# 2   jayllnn, buldak ramen noodles, noodles, realja...
# 5   stop recording me, stop attacking me, stop rec...
# 6   chel cosplay, Chel The Road To El Dorado, Chel...
# 8   cfn cabbage, Laffy Taffy, cfn kasai, bigcabbag...
# 10  lucid dreams, i still see your shadows, Hey Th...

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# ### Importing the necessary libraries

# %%
pip install cleantext
# Out:
# Collecting cleantext
#   Downloading cleantext-1.1.4-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: nltk in /Users/fridahntika/miniconda3/lib/python3.11/site-packages (from cleantext) (3.8.1)
# Requirement already satisfied: click in /Users/fridahntika/miniconda3/lib/python3.11/site-packages (from nltk->cleantext) (8.1.7)
# Requirement already satisfied: joblib in /Users/fridahntika/miniconda3/lib/python3.11/site-packages (from nltk->cleantext) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/fridahntika/miniconda3/lib/python3.11/site-packages (from nltk->cleantext) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/fridahntika/miniconda3/lib/python3.11/site-packages (from nltk->cleantext) (4.65.0)
# Downloading cleantext-1.1.4-py3-none-any.whl (4.9 kB)
# Installing collected packages: cleantext
# Successfully installed cleantext-1.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, types
import numpy as np
import re
import csv
import pandas as pd
from pandas import Series, DataFrame
from collections import Counter

# %%
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn
from cleantext import clean

# %% [markdown]
# ### Load the data

# %%
d1 = "/Users/fridahntika/Documents/CS315/Project 3/CS315-Project3-Group2/Data Analysis/user1.csv"
d2 = "/Users/fridahntika/Documents/CS315/Project 3/CS315-Project3-Group2/Data Analysis/user2.csv"
d3 = "/Users/fridahntika/Documents/CS315/Project 3/CS315-Project3-Group2/Data Analysis/user3.csv"
d4 = "/Users/fridahntika/Documents/CS315/Project 3/CS315-Project3-Group2/Data Analysis/user4.csv"
d5 = "/Users/fridahntika/Documents/CS315/Project 3/CS315-Project3-Group2/Data Analysis/user5.csv"
#d6
#d7
#d8
#d9
#d10

# %%
df1 = pd.read_csv(d1)
df1['User'] = 'User1'
df2 = pd.read_csv(d2)
df2['User'] = 'User2'
df3 = pd.read_csv(d3)
df3['User'] = 'User3'
df4 = pd.read_csv(d4)
df4['User'] = 'User4'
df5 = pd.read_csv(d5)
df5['User'] = 'User5'
df1.head()
# Out:
#                                    Vide descriptions   User
# 0  A couple bags of balloons, some left over deco...  User1
# 1  who would you bring on a trip to the Bahamas 🌺...  User1
# 2  Things to do in Cabo - Part 2! 🇲🇽 #cabo #cabos...  User1
# 3  All the details to our 4 day trip in Cabo. ✨ #...  User1
# 4  Let’s detox my son’s locs with me after 3 mont...  User1

# %% [markdown]
# Concatenate all of them in a single dataframe:

# %%
allDocs = pd.concat([df1, df2, df3, df4, df5])
allDocs.shape
# Out:
# (25679, 2)

# %%
allDocs.set_index('User', inplace = True)

# %%
allDocs
# Out:
#                                                                                                                                                                                                                                                                                            Vide descriptions
# User
# User1  A couple bags of balloons, some left over decorations from my other daughters birthday, a few borrowed items from friends and family, and an hour or so of work, and they had a night to remember!! But the real question is, do you remember your first sleepover?!? 🤍🎈 #birthday #sleepover #party
# User1                                                                                                                                                                                     who would you bring on a trip to the Bahamas 🌺 #honeymoon #travelbucketlist #thebahamas #caribbean #vacationinspo
# User1                                                                                                                                                                                                                      Things to do in Cabo - Part 2! 🇲🇽 #cabo #cabosanlucas #traveltok #travelblogger
# User1                                                                                                                                                                                                            All the details to our 4 day trip in Cabo. ✨ #fyp #whatwespent #cabo #cabosanlucas #travel
# User1                                                                                                                                                                                                                                                Let’s detox my son’s locs with me after 3 months #fypシ
# ...                                                                                                                                                                                                                                                                                                      ...
# User5                                                                                                                                                                                        How did he even pull her shes literally blackswan and hes well hes him #natalieportman #blackswan #greenscreen
# User5                                                                                                                                                                                                                                                  ila soo xariir.. message qeebta comment ga iigu reeb
# User5                                                                                                                                                                                                                                    The UK & US attack Yemen and Yemenis take to the street to protest
# User5                                                                                                                                                                                                                                                                              He better leave her now 🙈
# User5                                                                                                                                                                                                                      Tag a skinny friend who needs these🗣️ #Costco #Protein #Groceryshopping #fitness
#
# [25679 rows x 1 columns]

# %%
print(clean(allDocs['Vide descriptions'][1], no_emoji=True))
# Out:
# /var/folders/nd/my_j6y6s0p544s5nzvtvnntm0000gn/T/ipykernel_56660/1344178868.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   clean(allDocs['Vide descriptions'][1], no_emoji=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[293], line 1
# ----> 1 clean(allDocs['Vide descriptions'][1], no_emoji=True)
#
# TypeError: clean() got an unexpected keyword argument 'no_emoji'

# %%
def getHashtags(sentence):
    """Takes a sentence and returns hashtags if present"""
    if isinstance(sentence, str):
        hashtags = [tag.strip('#') for tag in sentence.split('#') if tag.strip('#')]
        return hashtags
    return []

# %%
toRemove = ['fyp', '#fyp', '#trending', 'trending', '#foryou', 'foryou', '#viral', 'viral', 'foryoupage', 'fy', 'fypage', 'tiktok', 'video', 'forypu', 'fup', 'everyonefyp', 'reaction', 'fypviral']

def remove_words(sentence):
    hashtags = getHashtags(sentence)
    final = []
    for hash in hashtags:
        #print(type(hash))
        if hash.lower() not in toRemove and hash not in final:
            final.append(hash)
    return ' '.join(final)

allDocs['Vide descriptions'] = allDocs['Vide descriptions'].apply(remove_words)
allDocs
# Out:
#                                                                                                                                                                                                                                                                                            Vide descriptions  \
# User
# User1  A couple bags of balloons, some left over decorations from my other daughters birthday, a few borrowed items from friends and family, and an hour or so of work, and they had a night to remember!! But the real question is, do you remember your first sleepover?!? 🤍🎈  birthday  sleepover  party
# User1                                                                                                                                                                                     who would you bring on a trip to the Bahamas 🌺  honeymoon  travelbucketlist  thebahamas  caribbean  vacationinspo
# User1                                                                                                                                                                                                                      Things to do in Cabo - Part 2! 🇲🇽  cabo  cabosanlucas  traveltok  travelblogger
# User1                                                                                                                                                                                                            All the details to our 4 day trip in Cabo. ✨  fyp  whatwespent  cabo  cabosanlucas  travel
# User1                                                                                                                                                                                                                                                Let’s detox my son’s locs with me after 3 months  fypシ
# ...                                                                                                                                                                                                                                                                                                      ...
# User5                                                                                                                                                                                        How did he even pull her shes literally blackswan and hes well hes him  natalieportman  blackswan  greenscreen
# User5                                                                                                                                                                                                                                                  ila soo xariir.. message qeebta comment ga iigu reeb
# User5                                                                                                                                                                                                                                    The UK & US attack Yemen and Yemenis take to the street to protest
# User5                                                                                                                                                                                                                                                                              He better leave her now 🙈
# User5                                                                                                                                                                                                                      Tag a skinny friend who needs these🗣️  Costco  Protein  Groceryshopping  fitness
#
#                                                                                                                                                                    terms
# User
# User1  [bags, balloons, birthday, borrowed, couple, daughters, decorations, family, friends, hour, items, left, night, party, question, real, remember, sleepover, work]
# User1                                                                          [bahamas, bring, caribbean, honeymoon, thebahamas, travelbucketlist, trip, vacationinspo]
# User1                                                                                                             [cabo, cabosanlucas, things, travelblogger, traveltok]
# User1                                                                                                 [cabo, cabosanlucas, day, details, fyp, travel, trip, whatwespent]
# User1                                                                                                                                    [detox, let, locs, months, son]
# ...                                                                                                                                                                  ...
# User5                                                                                          [blackswan, did, greenscreen, hes, literally, natalieportman, pull, shes]
# User5                                                                                                           [comment, iigu, ila, message, qeebta, reeb, soo, xariir]
# User5                                                                                                                          [attack, protest, street, yemen, yemenis]
# User5                                                                                                                                                    [better, leave]
# User5                                                                                            [costco, fitness, friend, groceryshopping, needs, protein, skinny, tag]
#
# [25679 rows x 2 columns]

# %% [markdown]
# ### Convert to document-term matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Initialize the vectorizer
vectorizer = CountVectorizer(
    strip_accents='unicode',
    stop_words='english',
    lowercase=True,
    token_pattern=r'\b[a-zA-Z]{3,}\b', # we want only words that contain letters and are 3 or more characters long
)

# Transform our data into the document-term matrix
dtm = vectorizer.fit_transform(allDocs['Vide descriptions'])
dtm
# Out:
# <25679x54660 sparse matrix of type '<class 'numpy.int64'>'
# 	with 242892 stored elements in Compressed Sparse Row format>

# %%
feature_names = vectorizer.get_feature_names_out()
feature_names
# Out:
# array(['ACCOUNT', 'Bonnibel', 'Eliana', ..., 'zyx', 'zyxbca', 'zyxcba'],
#       dtype=object)

# %%
def matrix2Doc(dtMatrix, features, index):
    """Turns each row of the document-term matrix into a list of terms"""
    row = dtMatrix.getrow(index).toarray()
    non_zero_indices = row.nonzero()[1]
    words = [features[idx] for idx in non_zero_indices]
    return words

# %%
allDocsAsTerms = [matrix2Doc(dtm, feature_names, i) for i in range(dtm.shape[0])]

# %%
allDocs['terms'] = allDocsAsTerms
pd.set_option("display.max_colwidth",1000)
allDocs.head()
# Out:
#                                                                                                                                                                                                                                                                                            Vide descriptions  \
# User
# User1  A couple bags of balloons, some left over decorations from my other daughters birthday, a few borrowed items from friends and family, and an hour or so of work, and they had a night to remember!! But the real question is, do you remember your first sleepover?!? 🤍🎈  birthday  sleepover  party
# User1                                                                                                                                                                                     who would you bring on a trip to the Bahamas 🌺  honeymoon  travelbucketlist  thebahamas  caribbean  vacationinspo
# User1                                                                                                                                                                                                                      Things to do in Cabo - Part 2! 🇲🇽  cabo  cabosanlucas  traveltok  travelblogger
# User1                                                                                                                                                                                                            All the details to our 4 day trip in Cabo. ✨  fyp  whatwespent  cabo  cabosanlucas  travel
# User1                                                                                                                                                                                                                                                Let’s detox my son’s locs with me after 3 months  fypシ
#
#                                                                                                                                                                    terms
# User
# User1  [bags, balloons, birthday, borrowed, couple, daughters, decorations, family, friends, hour, items, left, night, party, question, real, remember, sleepover, work]
# User1                                                                          [bahamas, bring, caribbean, honeymoon, thebahamas, travelbucketlist, trip, vacationinspo]
# User1                                                                                                             [cabo, cabosanlucas, things, travelblogger, traveltok]
# User1                                                                                                 [cabo, cabosanlucas, day, details, fyp, travel, trip, whatwespent]
# User1                                                                                                                                    [detox, let, locs, months, son]

# %% [markdown]
# ### Fitting the LDA model

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Step 1: Initialize the model
lda = LatentDirichletAllocation(n_components=5, # we are picking the number of topics arbitrarely at the moment
                                random_state=0)
# Step 2: Fit the model
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=0)

# %%
lda.components_.shape
# Out:
# (5, 54660)

# %%
doc_topic_dist = lda.transform(dtm)
doc_topic_dist
# Out:
# array([[0.00901355, 0.0089477 , 0.00889254, 0.00888191, 0.9642643 ],
#        [0.90962665, 0.0224601 , 0.02280923, 0.0226064 , 0.02249762],
#        [0.8842843 , 0.02932002, 0.02913477, 0.02860416, 0.02865674],
#        ...,
#        [0.03368404, 0.0343816 , 0.0333914 , 0.03439551, 0.86414745],
#        [0.06786592, 0.0678519 , 0.0672399 , 0.7289263 , 0.06811599],
#        [0.02289785, 0.02276447, 0.90936092, 0.02235417, 0.02262259]])

# %%
doc_topic_dist.shape
# Out:
# (25679, 5)

# %%
def display_topics(model, features, no_top_words):
    """Helper function to show the top words of a model"""
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" ".join([features[i]
                        for i in topic.argsort()[:-no_top_words-1:-1]])) # syntax for reversing a list [::-1]

display_topics(lda, feature_names, 30)
# Out:
# Topic 0:
# fyp foryou just like love know foryoupage viral replying college best trending dont funny stitch relatable good lol nyc time think avatarthelastairbender don tiktok comedy girl things kids way baby
# Topic 1:
# fyp replying viral just love foryoupage new like got goodomens day percyjackson foryou year time crowley funny bildadification davidtennant aziraphale bildaded percyjacksonandtheolympians pjo michaelsheen trending history life don song ineffablehusbands
# Topic 2:
# fyp foryou tiktok taylorswift foryoupage viral movie love greenscreen replying comedy africantiktok swiftie funny swifttok nigeriantiktok new stitch music taylor trending food bio cup happy link superbowl day best christmas
# Topic 3:
# fyp doctorwho foryou davidtennant like funny stitch viral tenthdoctor foryoupage nickiminaj rosetyler ghanatiktok skin did cat love day people doctor college time edit doctorwhoedit reddit megantheestallion drwho replying tenrose make
# Topic 4:
# fyp greenscreen viral replying like stitch foryou real time funny movie love video greenscreenvideo boston just trending truecrime foryoupage booktok meangirls need relatable youtube got loveisblind old family oliviarodrigo crime

# %%
def displayHeader(model, features, no_top_words):
    """Helper function to show the top words of a model"""
    topicNames = []
    for topic_idx, topic in enumerate(model.components_):
        topicNames.append(f"Topic {topic_idx}: " + (", ".join([features[i]
                             for i in topic.argsort()[:-no_top_words-1:-1]])))
    return topicNames

# %%
# column names
topicnames = displayHeader(lda, feature_names, 5)

# index names
docnames = allDocs.index.tolist() # We will use the original names of the documents

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(doc_topic_dist, 3), 
                                 columns=topicnames, 
                                 index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1) # finds the maximum argument
df_document_topic['dominant_topic'] = dominant_topic

df_document_topic
# Out:
#        Topic 0: fyp, foryou, just, like, foryoupage  \
# User1                                         0.009
# User1                                         0.910
# User1                                         0.884
# User1                                         0.020
# User1                                         0.034
# ...                                             ...
# User5                                         0.019
# User5                                         0.022
# User5                                         0.033
# User5                                         0.068
# User5                                         0.023
#
#        Topic 1: fyp, replying, viral, just, love  \
# User1                                      0.009
# User1                                      0.022
# User1                                      0.029
# User1                                      0.919
# User1                                      0.865
# ...                                          ...
# User5                                      0.019
# User5                                      0.022
# User5                                      0.035
# User5                                      0.068
# User5                                      0.023
#
#        Topic 2: fyp, foryou, tiktok, taylorswift, foryoupage  \
# User1                                                  0.009
# User1                                                  0.023
# User1                                                  0.029
# User1                                                  0.020
# User1                                                  0.033
# ...                                                      ...
# User5                                                  0.019
# User5                                                  0.022
# User5                                                  0.033
# User5                                                  0.067
# User5                                                  0.909
#
#        Topic 3: fyp, doctorwho, foryou, davidtennant, like  \
# User1                                                0.009
# User1                                                0.023
# User1                                                0.029
# User1                                                0.020
# User1                                                0.034
# ...                                                    ...
# User5                                                0.019
# User5                                                0.023
# User5                                                0.034
# User5                                                0.729
# User5                                                0.022
#
#        Topic 4: fyp, greenscreen, viral, replying, like  dominant_topic
# User1                                             0.964               4
# User1                                             0.023               0
# User1                                             0.029               0
# User1                                             0.020               1
# User1                                             0.034               1
# ...                                                 ...             ...
# User5                                             0.925               4
# User5                                             0.910               4
# User5                                             0.864               4
# User5                                             0.068               3
# User5                                             0.023               2
#
# [25679 rows x 6 columns]

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Sentences']
df_topic_distribution
# Out:
#    Topic Num  Num Sentences
# 0          0           6368
# 1          3           5303
# 2          1           4999
# 3          2           4551
# 4          4           4458

# %%
#from sklearn.model_selection import GridSearchCV

# %%
# We are going to test multiple values for the number of topics
#search_params = {'n_components': [5, 10, 15, 20, 25, 30, 35]}

# Initialize the LDA model
#lda = LatentDirichletAllocation()

# Initialize a Grid Search with cross-validation instance
#grid = GridSearchCV(lda, param_grid=search_params)

# Do the Grid Search
#grid.fit(dtm)

# %%
#grid.cv_results_

# %%
# Best Model
#best_lda_model = grid.best_estimator_

# Model Parameters
#print("Best Model's Params: ", grid.best_params_)

# Log Likelihood Score
#print("Best Log Likelihood Score: ", grid.best_score_)

# Perplexity
#print("Model Perplexity: ", best_lda_model.perplexity(dtm))

# %%
#search_params = {'n_components': [1,2,3,4,5,6]}

#lda = LatentDirichletAllocation()
#grid = GridSearchCV(lda, param_grid=search_params)

#grid.fit(dtm)

# Best Model
#best_lda_model = grid.best_estimator_

# Model Parameters
#print("Best Model's Params: ", grid.best_params_)

# Log Likelihood Score
#print("Best Log Likelihood Score: ", grid.best_score_)

# Perplexity
#print("Model Perplexity: ", best_lda_model.perplexity(dtm))

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# ### Importing the necessary libraries

# %%
pip install clean-text

# %%
import os, types
import numpy as np
import re
import csv
import json
import pandas as pd
from collections import Counter

# %%
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from cleantext import clean
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the data

# %%
def jsonToDF(name):
    """Read a list of sentences from the JSON file, store them in a dataframe"""
    
    with open(f"{name}.json") as fin:
        textList = json.load(fin)

    # create a name for each document, based on its category
    indexNames = [f"{name}" for i in range(len(textList))]

    # create the dataframe, it will have one column and one index
    df = pd.DataFrame(data=textList, index=indexNames)
    df.columns = ['document']
    return df

# %%
user1 = jsonToDF("user1")
user2 = jsonToDF("user2")
user3 = jsonToDF("user3")
user4 = jsonToDF("user4")
user5 = jsonToDF("user5")
user6 = jsonToDF("user6")
user7 = jsonToDF("user7")
user8 = jsonToDF("user8")
user9 = jsonToDF("user9")
user10 = jsonToDF("user10")
user6.shape
# Out:
# (38, 1)

# %%
#remove duplicates and missing values
def cleanDf(df):
    df.dropna(subset=['document'])
    df.drop_duplicates(inplace=True)
    return df

# %%
allDocs = [user1, user2, user3, user4, user5, user6, user7, user8, user9, user10]
for df in allDocs:
    df = cleanDf(df)
user6.shape
# Out:
# (37, 1)

# %%
#user5

# %%
#removes emojis from text
RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)

def strip_emoji(text):
    if not isinstance(text, str):  # Check if sentence is not a string
        return str(text)
    return RE_EMOJI.sub(r'', text)

user6['document'] = user6['document'].apply(strip_emoji)

# %%
def splitHashtags(sentence):
    """Takes a sentence and splits hashtags if present"""
    if isinstance(sentence, str):
        hashtags = [tag.strip('#') for tag in sentence.split('#') if tag.strip('#')]
        return ''.join(hashtags)
    return []

user6['document'] = user6['document'].apply(splitHashtags)

# %%
toRemove = ['fyp', 'trending', 'foryou', 'viral', 'foryoupage', 'fy', 'fypage', 'blowthisup', 'tiktok', 'video', 'forypu', 'fup', 'everyonefyp', 'reaction', 'fypviral', 'relatable']

def remove_words(sentence):
    """Takes a sentence and removes emojis and popular phrases"""
    if not isinstance(sentence, str):  # Check if sentence is not a string
        return str(sentence)
    words = sentence.split()
    final = []

    for word in words:
        # Check if the word or hashtag is in toRemove list
        if word.lower() not in toRemove:
            final.append(word)

    return ' '.join(final)

user6['document'] = user6['document'].apply(remove_words)
pd.set_option("display.max_colwidth",1000)
user6
# Out:
#                                                                                                                                                                                                                                                                                                                                                    document
# user6                                                                                                                                                                                                                                                                                                                                               noodles
# user6                                                                                                                                                                                  If Grama Sandy comes up to you in a store and asks you to record her, would you do it? sandybepsycho recordme strangers viraltiktok noshame happymonday february22nd
# user6                                                                                                                                                                                     Im hearing everyone out || @Rat || ac mp3 server || dt @max || theroadtoeldorado chel pixar disney cheledit edit blowthisupp dontletthisflop quizkaii foryourpage
# user6                                                                                                                                                                                                                                                                                 Im just trying to see if my face clean xybca cfn mammoo thatoneperson
# user6                                                                                                                                                                    aisha, Hakari From Jjk, always bet on hakari, hakari in jjk anime, Hakari And Kashimo, hakari pulling up, Hakari Theme Song, black hakari, Hakari Vs Kashimo JJK, hakari vs uraume
# user6                                                                                                                                                                                                                                                                                                                                                   nan
# user6                                                                                                                   Middle Child, middle sibling, im the middle child, i'm the middle sibling, middle child syndrome, i'm the oldest child, i'm the middle sibling cut off, im the oldest sibling, i'm the middle child of course, sibling anthem check
# user6                                                                                                                                                                                                                                                                                                        mirandahshaul, miranda marie, igmirandahhmarie
# user6  remote controlled in public girlfriend prank, remote controlled in public, remote controlled in public girlfriend, what is it finna play .. woahhhh, keeping date nights interesting, remote controlled in public girlfriend prank date, remote controlled in public girlfriend date, remote controlled underwater, finna play, what's it finna play
# user6                                                                                                                         How To Clean Ears, bobby pin, bobby pin in ear, how to clean ears correctly bobby pin, cleaning ear with bobby pin, how to clean ears with bobby pin, cleaning ear wax, q tip in ear, how to properly clean your ears, q tips
# user6                                                                                                                                                                                                   Megatron Family Guy, parents aren't home you know what, Mainecoon Cat, kitties, Kitten Videos, Pet Cat, pets, Cats Of TikTok, small cat, Kittens Of
# user6                                                                                                                                                                                            Car Air Freshener, Car Freshener, Car Freshener Scent, Car Products, Car Scents, Stuff For Car, Car Gadget, Car Refresher Perfume, Car Fragrance, Car Care
# user6                                                                                                                                                                             car accessories, car charger, retractable car charger, 4 in 1 car charger, Shop, store shop, 4 in 1 retractable charger, bluetooth car adapter, portable charger, Charger
# user6                                                                                                                                                                                                 Halara Leggings, halara, Halara Pants, Leggings, halara joggers, halara_official, Halara Clothing, leggings of TikTok, Leggins Outfit, Black Leggings

# %% [markdown]
# Jaccard index on suggested words and video descriptons between users

# %% [markdown]
# ### Convert to document-term matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Initialize the vectorizer
vectorizer = CountVectorizer(
    strip_accents='unicode',
    stop_words='english',
    lowercase=True,
    token_pattern=r'\b[a-zA-Z]{3,}\b', # we want only words that contain letters and are 3 or more characters long
)

# Transform our data into the document-term matrix
dtm = vectorizer.fit_transform(user6['document'])
dtm
# Out:
# <37x266 sparse matrix of type '<class 'numpy.int64'>'
# 	with 305 stored elements in Compressed Sparse Row format>

# %%
feature_names = vectorizer.get_feature_names_out()
feature_names
# Out:
# array(['accessories', 'adapter', 'ain', 'air', 'aisha', 'anime', 'anthem',
#        'aren', 'asks', 'attacking', 'aylecia', 'bell', 'bendigo', 'bet',
#        'big', 'billionaire', 'black', 'blowthisupp', 'bluetooth', 'bobby',
#        'bose', 'bro', 'buldak', 'buying', 'cabbage', 'came', 'car',
#        'caraccessories', 'care', 'carfreshener', 'cassie', 'cat', 'cats',
#        'cfn', 'change', 'charger', 'check', 'chel', 'cheledit', 'child',
#        'clean', 'cleaning', 'clothing', 'coffee', 'comes', 'compilation',
#        'controlled', 'cooking', 'correctly', 'cosplay', 'course', 'cut',
#        'dancando', 'date', 'dating', 'dawg', 'days', 'delilah',
#        'dialogue', 'digits', 'dio', 'disney', 'dog', 'dontletthisflop',
#        'dorado', 'dreams', 'ear', 'ears', 'ebarb', 'edit', 'edits',
#        'emiliexpirez', 'euphoria', 'face', 'family', 'feels', 'finna',
#        'food', 'foryourpage', 'fragrance', 'freshener',
#        'freshenersairfreshener', 'fyptiktokshopusa', 'gadget', 'gadgets',
#        'gavin', 'getting', 'girlfriend', 'glad', 'going', 'grama',
#        'great', 'guess', 'guy', 'gym', 'hakari', 'halara',
#        'halaraleggins', 'happymonday', 'hearing', 'hes', 'hey', 'home',
#        'hound', 'hunter', 'husband', 'iconic', 'igmirandahhmarie',
#        'interesting', 'interior', 'jayllnn', 'jjk', 'joggers', 'juice',
#        'juicewrld', 'just', 'kasai', 'kashimo', 'keeping', 'kiss',
#        'kitten', 'kittens', 'kitties', 'know', 'laffy', 'laugh',
#        'leggings', 'leggins', 'life', 'like', 'lil', 'lines', 'live',
#        'love', 'lucid', 'luciddreams', 'lyrics', 'maddy', 'magnus',
#        'mainecoon', 'mammoo', 'marie', 'marriage', 'married', 'marry',
#        'max', 'megatron', 'meme', 'mia', 'michael', 'middle', 'miranda',
#        'mirandahshaul', 'mirror', 'mirrors', 'money', 'muffled',
#        'mulheres', 'myer', 'nan', 'nate', 'need', 'night', 'nights',
#        'noodles', 'noshame', 'obsessed', 'ocd', 'oldest', 'original',
#        'outfit', 'pants', 'parents', 'perez', 'perfume', 'pet', 'pets',
#        'phone', 'phoneaccessories', 'pin', 'pixar', 'play', 'portable',
#        'prank', 'products', 'promise', 'properly', 'public', 'pulling',
#        'qtips', 'quick', 'quizkaii', 'quote', 'ramen', 'rat', 'real',
#        'realjayllnn', 'really', 'reasy', 'record', 'recording',
#        'recordme', 'refresher', 'remote', 'replying', 'retractable',
#        'rich', 'road', 'room', 'said', 'sandy', 'sandybepsycho', 'scenes',
#        'scent', 'scents', 'server', 'shadow', 'shadows', 'shop',
#        'shoutout', 'showed', 'sibling', 'small', 'smellgood', 'smoke',
#        'song', 'songs', 'soothes', 'sounding', 'spend', 'spicy', 'stop',
#        'store', 'strangers', 'stuff', 'syndrome', 'szn', 'taffy',
#        'thatoneperson', 'thats', 'theme', 'theroadtoeldorado', 'throwing',
#        'tiktok', 'tiktokdeals', 'tiktokshop', 'tip', 'tips', 'travis',
#        'trends', 'trying', 'tulio', 'tummycontrol', 'underwater',
#        'uraume', 'using', 'version', 'videos', 'viraltiktok', 'wax',
#        'window', 'woahhhh', 'wrld', 'xybca', 'yesterday', 'zoe'],
#       dtype=object)

# %%
def matrix2Doc(dtMatrix, features, index):
    """Turns each row of the document-term matrix into a list of terms"""
    row = dtMatrix.getrow(index).toarray()
    non_zero_indices = row.nonzero()[1]
    words = [features[idx] for idx in non_zero_indices]
    return words

# %%
user6AsTerms = [matrix2Doc(dtm, feature_names, i) for i in range(dtm.shape[0])]

# %%
user6['terms'] = user6AsTerms
pd.set_option("display.max_colwidth",1000)
user6.head()
# Out:
#                                                                                                                                                                    document  \
# user6                                                                                                                                                               noodles
# user6  If Grama Sandy comes up to you in a store and asks you to record her, would you do it? sandybepsycho recordme strangers viraltiktok noshame happymonday february22nd
# user6     Im hearing everyone out || @Rat || ac mp3 server || dt @max || theroadtoeldorado chel pixar disney cheledit edit blowthisupp dontletthisflop quizkaii foryourpage
# user6                                                                                                 Im just trying to see if my face clean xybca cfn mammoo thatoneperson
# user6                                                                                                                                                 Dc @emiliexpirez !!!!
#
#                                                                                                                                           terms
# user6                                                                                                                                 [noodles]
# user6                         [asks, comes, grama, happymonday, noshame, record, recordme, sandy, sandybepsycho, store, strangers, viraltiktok]
# user6  [blowthisupp, chel, cheledit, disney, dontletthisflop, edit, foryourpage, hearing, max, pixar, quizkaii, rat, server, theroadtoeldorado]
# user6                                                                            [cfn, clean, face, just, mammoo, thatoneperson, trying, xybca]
# user6                                                                                                                            [emiliexpirez]

# %% [markdown]
# ### Fitting the LDA model

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Step 1: Initialize the model
lda = LatentDirichletAllocation(n_components=15, # we are picking the number of topics arbitrarily at the moment
                                random_state=0)
# Step 2: Fit the model
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=15, random_state=0)

# %%
lda.components_.shape
# Out:
# (15, 266)

# %%
doc_topic_dist = lda.transform(dtm)
doc_topic_dist
# Out:
# array([[0.03333333, 0.03333333, 0.03333333, 0.03333333, 0.53333333,
#         0.03333333, 0.03333333, 0.03333333, 0.03333333, 0.03333333,
#         0.03333333, 0.03333333, 0.03333333, 0.03333333, 0.03333333],
#        [0.00512821, 0.00512821, 0.00512821, 0.00512821, 0.00512821,
#         0.00512821, 0.00512821, 0.92820512, 0.00512821, 0.00512821,
#         0.00512821, 0.00512821, 0.00512821, 0.00512821, 0.00512821],
#        [0.00444444, 0.00444444, 0.00444451, 0.00444444, 0.00444444,
#         0.00444444, 0.00444444, 0.00444444, 0.00444444, 0.93777771,
#         0.00444444, 0.00444444, 0.00444444, 0.00444444, 0.00444444],
#        [0.89629628, 0.00740741, 0.00740741, 0.00740741, 0.00740741,
#         0.00740741, 0.00740741, 0.00740741, 0.00740741, 0.00740741,
#         0.00740742, 0.00740741, 0.00740741, 0.00740741, 0.00740741],
#        [0.03333333, 0.03333333, 0.03333333, 0.03333333, 0.03333333,
#         0.03333333, 0.03333333, 0.53333333, 0.03333333, 0.03333333,
#         0.03333333, 0.03333333, 0.03333333, 0.03333333, 0.03333333],
#        [0.00740741, 0.00740741, 0.00740741, 0.00740741, 0.00740741,
#         0.00740741, 0.00740741, 0.00740741, 0.00740741, 0.00740741,
#         0.00740741, 0.00740741, 0.00740741, 0.00740744, 0.89629627],
#        [0.00833334, 0.00833333, 0.00833333, 0.00833333, 0.00833336,
#         0.00833333, 0.00833333, 0.00833333, 0.00833333, 0.00833333,
#         0.00833333, 0.00833334, 0.8833333 , 0.00833333, 0.00833333],
#        [0.00833335, 0.00833333, 0.00833333, 0.00833333, 0.38333304,
#         0.50833356, 0.00833333, 0.00833333, 0.00833333, 0.00833333,
#         0.00833333, 0.00833334, 0.00833335, 0.00833335, 0.00833333],
#        [0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
.00277778, 0.00277778, 0.00277778, 0.00277778, 0.00277778,
#         0.00277778, 0.00277778, 0.00277778, 0.00277778, 0.96111111],
#        [0.0031746 , 0.0031746 , 0.0031746 , 0.0031746 , 0.0031746 ,
#         0.0031746 , 0.0031746 , 0.0031746 , 0.95555555, 0.0031746 ,
#         0.0031746 , 0.0031746 , 0.0031746 , 0.0031746 , 0.00317461],
#        [0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.94509804,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157]])

# %%
doc_topic_dist.shape
# Out:
# (37, 15)

# %%
def display_topics(model, features, no_top_words):
    """Helper function to show the top words of a model"""
    for topic_idx, topic in enumerate(model.components_):                                                                                                             
        print(f"Topic {topic_idx}:")
        print(" ".join([features[i]
                        for i in topic.argsort()[:-no_top_words-1:-1]]))

display_topics(lda, feature_names, 30)
# Out:
# Topic 0:
# just face xybca trying mammoo thatoneperson nan cfn clean version emiliexpirez igmirandahhmarie live love laugh money course kitten mirandahshaul miranda marie getting middle hes thats dawg need reasy gym digits
# Topic 1:
# came glad date version emiliexpirez just nan igmirandahhmarie love live laugh money course kitten mirandahshaul miranda marie getting middle dawg thats hes need reasy gym digits guess magnus phone gavin
# Topic 2:
# chel road dorado disney edits cosplay michael myer tulio bell kiss version emiliexpirez just nan igmirandahhmarie live laugh love money course kitten mirandahshaul marie miranda getting middle dawg thats hes
# Topic 3:
# zoe cfn ebarb taffy cabbage mirrors mirror laffy igmirandahhmarie car hunter kasai travis interior using window big dancando throwing compilation mulheres marie miranda mirandahshaul emiliexpirez version just nan laugh love
# Topic 4:
# noodles euphoria maddy kiss nate ramen jayllnn buldak videos scenes perez dialogue change promise cassie bendigo lines coffee iconic realjayllnn food spicy cooking money course just dating rich married husband
# Topic 5:
# husband married rich mia dio dating getting billionaire marriage marry life just course money emiliexpirez version nan igmirandahhmarie love laugh live kitten mirandahshaul miranda marie middle hes thats dawg need
# Topic 6:
# bose phoneaccessories soothes ocd caraccessories replying gadgets tiktokdeals tiktokshop charger car emiliexpirez version just nan igmirandahhmarie live love laugh money course kitten miranda marie mirandahshaul getting middle dawg thats hes
# Topic 7:
# wrld juice dreams lucid cat shadows room hey delilah kitten songs shadow lyrics parents home pets pet cats small megatron mainecoon aren family guy know kitties kittens recordme viraltiktok grama
# Topic 8:
# charger car retractable shop store accessories adapter bluetooth portable emiliexpirez version just nan igmirandahhmarie laugh love live money course kitten miranda mirandahshaul marie getting middle dawg hes thats need gym
# Topic 9:
# halara leggings black tiktok joggers clothing outfit leggins pants theroadtoeldorado pixar blowthisupp edit dontletthisflop quizkaii rat server foryourpage cheledit max hearing phone gavin guess magnus digits disney chel emiliexpirez version
# Topic 10:
# pin bobby clean ear ears cleaning tips correctly properly wax tip version emiliexpirez just nan igmirandahhmarie live love laugh money course kitten marie miranda mirandahshaul getting middle dawg thats hes
# Topic 11:
# controlled remote public girlfriend date play finna prank nights interesting keeping woahhhh underwater thats dawg hes kitten just version emiliexpirez nan igmirandahhmarie love laugh live money course miranda marie mirandahshaul
# Topic 12:
# euphoria just feels yesterday szn like qtips days sounding aylecia muffled gym reasy getting emiliexpirez version nan igmirandahhmarie live laugh love money course kitten miranda mirandahshaul marie middle dawg thats
# Topic 13:
# hakari middle child sibling jjk oldest kashimo course money need anthem check syndrome cut pulling song bet anime theme uraume aisha said quote showed going spend obsessed buying trends great
# Topic 14:
# car stop recording record freshener hound dog attacking scent air fragrance products perfume care quick stuff real refresher original scents meme gadget ain smellgood smoke really carfreshener freshenersairfreshener fyptiktokshopusa juicewrld

# %%
def displayHeader(model, features, no_top_words):
    """Helper function to show the top words of a model"""
    topicNames = []
    for topic_idx, topic in enumerate(model.components_):
        topicNames.append(f"Topic {topic_idx}: " + (", ".join([features[i]
                             for i in topic.argsort()[:-no_top_words-1:-1]])))
    return topicNames

# %%
# column names
topicnames = displayHeader(lda, feature_names, 0)

# index names
docnames = user6.index.tolist() # We will use the original names of the documents

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(doc_topic_dist, 3), 
                                 columns=topicnames, 
                                 index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1) # finds the maximum argument
df_document_topic['dominant_topic'] = dominant_topic

df_document_topic.tail()
# Out:
#        Topic 0:   Topic 1:   Topic 2:   Topic 3:   Topic 4:   Topic 5:   \
# user6      0.002      0.002      0.002      0.002      0.002      0.002
# user6      0.003      0.003      0.003      0.003      0.003      0.003
# user6      0.003      0.003      0.003      0.003      0.003      0.003
# user6      0.003      0.003      0.003      0.003      0.003      0.003
# user6      0.004      0.004      0.004      0.004      0.004      0.004
#
#        Topic 6:   Topic 7:   Topic 8:   Topic 9:   Topic 10:   Topic 11:   \
# user6      0.002      0.002      0.002      0.002       0.969       0.002
# user6      0.003      0.956      0.003      0.003       0.003       0.003
# user6      0.003      0.003      0.003      0.003       0.003       0.003
# user6      0.003      0.003      0.956      0.003       0.003       0.003
# user6      0.004      0.004      0.004      0.945       0.004       0.004
#
#        Topic 12:   Topic 13:   Topic 14:   dominant_topic
# user6       0.002       0.002       0.002              10
# user6       0.003       0.003       0.003               7
# user6       0.003       0.003       0.961              14
# user6       0.003       0.003       0.003               8
# user6       0.004       0.004       0.004               9

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Sentences']
df_topic_distribution
# Out:
#     Topic Num  Num Sentences
# 0           7              5
# 1          14              4
# 2          13              4
# 3           3              4
# 4           4              3
# 5           9              3
# 6          12              3
# 7           0              2
# 8           5              2
# 9          11              2
# 10          1              1
# 11          6              1
# 12          2              1
# 13         10              1
# 14          8              1

# %%
# Extract data from DataFrame columns
x_values = df_topic_distribution['Topic Num']
y_values = df_topic_distribution['Num Sentences']

# Plot the bar chart
plt.style.use('classic')
plt.bar(x_values, y_values, color='darkred')
plt.grid(axis='y', linestyle='solid', linewidth=0.5, alpha=0.5)
plt.xlim(-1, 15)

# Add labels and title
plt.xlabel('Topics')
plt.ylabel('Sent ence Counts')
plt.title('user6 Bar Chart of Topics vs. Sentences')

# Rotate x-axis labels for better readability (if needed)
plt.xticks(rotation=45)

# Show the plot
plt.show()

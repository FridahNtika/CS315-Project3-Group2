# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# ### Importing the necessary libraries

# %%
pip install clean-text

# %%
import os, types
import numpy as np
import re
import csv
import json
import pandas as pd
from collections import Counter

# %%
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from cleantext import clean
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the data

# %%
def jsonToDF(name):
    """Read a list of sentences from the JSON file, store them in a dataframe"""
    
    with open(f"{name}.json") as fin:
        textList = json.load(fin)

    # create a name for each document, based on its category
    indexNames = [f"{name}" for i in range(len(textList))]

    # create the dataframe, it will have one column and one index
    df = pd.DataFrame(data=textList, index=indexNames)
    df.columns = ['document']
    return df

# %%
user1 = jsonToDF("user1")
user2 = jsonToDF("user2")
user3 = jsonToDF("user3")
user4 = jsonToDF("user4")
user5 = jsonToDF("user5")
user6 = jsonToDF("user6")
user7 = jsonToDF("user7")
user8 = jsonToDF("user8")
user9 = jsonToDF("user9")
user10 = jsonToDF("user10")

# %% [markdown]
# Concatenate all of them in a single dataframe:

# %%
allDocs = pd.concat([user1, user2, user3, user4, user5, user6, user7, user8, user9, user10])
allDocs.shape
# Out:
# (115444, 1)

# %%
#remove duplicates and missing values
def cleanDf(df):
    df.dropna(subset=['document'])
    df.drop_duplicates(inplace=True)
    return df

# %%
allDocs = cleanDf(allDocs)
allDocs.shape
# Out:
# (81466, 1)

# %%
pd.set_option("display.max_colwidth",1000)
allDocs.head()
# Out:
#                                                                                                                                                                                                                                                                                                     document
# user1  A couple bags of balloons, some left over decorations from my other daughters birthday, a few borrowed items from friends and family, and an hour or so of work, and they had a night to remember!! But the real question is, do you remember your first sleepover?!? 🤍🎈 #birthday #sleepover #party
# user1                                                                                                                                                                                     who would you bring on a trip to the Bahamas 🌺 #honeymoon #travelbucketlist #thebahamas #caribbean #vacationinspo
# user1                                                                                                                                                                                                                      Things to do in Cabo - Part 2! 🇲🇽 #cabo #cabosanlucas #traveltok #travelblogger
# user1                                                                                                                                                                                                            All the details to our 4 day trip in Cabo. ✨ #fyp #whatwespent #cabo #cabosanlucas #travel
# user1                                                                                                                                                                                                                                                Let’s detox my son’s locs with me after 3 months #fypシ

# %%
#removes emojis from text
RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)

def strip_emoji(text):
    if not isinstance(text, str):  # Check if sentence is not a string
        return str(text)
    return RE_EMOJI.sub(r'', text)

allDocs['document'] = allDocs['document'].apply(strip_emoji)

# %%
def splitHashtags(sentence):
    """Takes a sentence and splits hashtags if present"""
    if isinstance(sentence, str):
        hashtags = [tag.strip('#') for tag in sentence.split('#') if tag.strip('#')]
        return ''.join(hashtags)
    return []

allDocs['document'] = allDocs['document'].apply(splitHashtags)

# %%
toRemove = ['fyp', 'trending', 'foryou', 'viral', 'foryoupage', 'fy', 'fypage', 'blowthisup', 'tiktok', 'video', 'forypu', 'fup', 'everyonefyp', 'reaction', 'fypviral', 'relatable']

def remove_words(sentence):
    """Takes a sentence and removes emojis and popular phrases"""
    if not isinstance(sentence, str):  # Check if sentence is not a string
        return str(sentence)
    words = sentence.split()
    final = []

    for word in words:
        # Check if the word or hashtag is in toRemove list
        if word.lower() not in toRemove:
            final.append(word)

    return ' '.join(final)

allDocs['document'] = allDocs['document'].apply(remove_words)
pd.set_option("display.max_colwidth",1000)
allDocs
# Out:
#                                                                                                                                                                                                                                                                                               document
# user1   A couple bags of balloons, some left over decorations from my other daughters birthday, a few borrowed items from friends and family, and an hour or so of work, and they had a night to remember!! But the real question is, do you remember your first sleepover?!? birthday sleepover party
# user1                                                                                                                                                                                       who would you bring on a trip to the Bahamas honeymoon travelbucketlist thebahamas caribbean vacationinspo
# user1                                                                                                                                                                                                                         Things to do in Cabo - Part 2! cabo cabosanlucas traveltok travelblogger
# user1                                                                                                                                                                                                                All the details to our 4 day trip in Cabo. ✨ whatwespent cabo cabosanlucas travel
# user1                                                                                                                                                                                                                                            Let’s detox my son’s locs with me after 3 months fypシ
# ...                                                                                                                                                                                                                                                                                                ...
# user10                                                           Brenda Song, macaulay culkin, rory culkin, Kieran Culkin, macaulay culkin and brenda song, macaulay culkin hollywood star, macaulay culkin brother, macaulay culkin voice, Brenda Song And Macaulay, what happened to macaulay culkin
# user10                                                                                                                                                               Disney 100, cactus, cactus dancing toy, cactus toys, bebes asustandose, cactus baby toys, cactus plant, videos, Baby Gifts, Funny
# user10                                                                                                                  woongki, woongki and seunghwan, Hyeongjun Cravity, woong ki and hyeongjun, cravity band, Boys Planet, Hyeongjun Edits, Kim Ji Woong - Boys Planet, cravityofficial, kpop edits
# user10  Look Around Everybody On Mute, were you silent or silenced, but are you her girl, look around everybody on mute teacher, Were You Silent Or Were You Silenced, Everybody On Mute Beyonce, but are you her man, Everybody On Mute Beyonce Yall Won, Her Man My Man Two Words, Everybody On Mute
# user10                                                                                                                          Kindle, kindle holder with remote, Kindle Accessories, kobo vs kindle, Kindle Paperwhite, kindle tablet, Kindle Decorating, kindle unlimited, kindle stickers, Booktok
#
# [81466 rows x 1 columns]

# %% [markdown]
# Jaccard index on suggested words and video descriptons between users

# %% [markdown]
# ### Convert to document-term matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Initialize the vectorizer
vectorizer = CountVectorizer(
    strip_accents='unicode',
    stop_words='english',
    lowercase=True,
    token_pattern=r'\b[a-zA-Z]{3,}\b', # we want only words that contain letters and are 3 or more characters long
)

# Transform our data into the document-term matrix
dtm = vectorizer.fit_transform(allDocs['document'])
dtm
# Out:
# <81466x110516 sparse matrix of type '<class 'numpy.int64'>'
# 	with 818136 stored elements in Compressed Sparse Row format>

# %%
feature_names = vectorizer.get_feature_names_out()
feature_names
# Out:
# array(['aaa', 'aaaa', 'aaaaaaaaaaa', ..., 'zyzz', 'zzuzzhas',
#        'zzzachariah'], dtype=object)

# %%
def matrix2Doc(dtMatrix, features, index):
    """Turns each row of the document-term matrix into a list of terms"""
    row = dtMatrix.getrow(index).toarray()
    non_zero_indices = row.nonzero()[1]
    words = [features[idx] for idx in non_zero_indices]
    return words

# %%
allDocsAsTerms = [matrix2Doc(dtm, feature_names, i) for i in range(dtm.shape[0])]

# %%
allDocs['terms'] = allDocsAsTerms
pd.set_option("display.max_colwidth",1000)
allDocs.head()
# Out:
#                                                                                                                                                                                                                                                                                              document  \
# user1  A couple bags of balloons, some left over decorations from my other daughters birthday, a few borrowed items from friends and family, and an hour or so of work, and they had a night to remember!! But the real question is, do you remember your first sleepover?!? birthday sleepover party
# user1                                                                                                                                                                                      who would you bring on a trip to the Bahamas honeymoon travelbucketlist thebahamas caribbean vacationinspo
# user1                                                                                                                                                                                                                        Things to do in Cabo - Part 2! cabo cabosanlucas traveltok travelblogger
# user1                                                                                                                                                                                                               All the details to our 4 day trip in Cabo. ✨ whatwespent cabo cabosanlucas travel
# user1                                                                                                                                                                                                                                           Let’s detox my son’s locs with me after 3 months fypシ
#
#                                                                                                                                                                    terms
# user1  [bags, balloons, birthday, borrowed, couple, daughters, decorations, family, friends, hour, items, left, night, party, question, real, remember, sleepover, work]
# user1                                                                          [bahamas, bring, caribbean, honeymoon, thebahamas, travelbucketlist, trip, vacationinspo]
# user1                                                                                                             [cabo, cabosanlucas, things, travelblogger, traveltok]
# user1                                                                                                      [cabo, cabosanlucas, day, details, travel, trip, whatwespent]
# user1                                                                                                                                    [detox, let, locs, months, son]

# %% [markdown]
# ### Fitting the LDA model

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
#from sklearn.model_selection import GridSearchCV

# We are going to test multiple values for the number of topics
#search_params = {'n_components': [5, 10, 15, 20, 25, 30, 35]}

# Initialize the LDA model
#lda = LatentDirichletAllocation()

# Initialize a Grid Search with cross-validation instance
#grid = GridSearchCV(lda, param_grid=search_params)

# Do the Grid Search
#grid.fit(dtm)

# %%
#grid.cv_results_

# %%
# Best Model
#best_lda_model = grid.best_estimator_

# Model Parameters
#print("Best Model's Params: ", grid.best_params_)

# Log Likelihood Score
#print("Best Log Likelihood Score: ", grid.best_score_)

# Perplexity
#print("Model Perplexity: ", best_lda_model.perplexity(dtm))

# %%
# Step 1: Initialize the model
lda = LatentDirichletAllocation(n_components=15, # we are picking the number of topics arbitrarely at the moment
                                random_state=0)
# Step 2: Fit the model
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=15, random_state=0)

# %%
lda.components_.shape
# Out:
# (15, 110516)

# %%
doc_topic_dist = lda.transform(dtm)
doc_topic_dist
# Out:
# array([[0.15339924, 0.00289856, 0.20822302, ..., 0.17113114, 0.00289856,
#         0.00289857],
#        [0.00740741, 0.14944674, 0.33803962, ..., 0.00740743, 0.00740741,
#         0.00740741],
#        [0.00952381, 0.240966  , 0.00952382, ..., 0.51176378, 0.00952382,
#         0.00952381],
#        ...,
#        [0.00317461, 0.00317461, 0.0031746 , ..., 0.00317461, 0.12826089,
#         0.0031746 ],
#        [0.2989361 , 0.00246914, 0.00246914, ..., 0.00246914, 0.00246914,
#         0.00246914],
#        [0.00333334, 0.00333334, 0.00333335, ..., 0.00333336, 0.00333333,
#         0.11015658]])

# %%
doc_topic_dist.shape
# Out:
# (81466, 15)

# %%
def display_topics(model, features, no_top_words):
    """Helper function to show the top words of a model"""
    for topic_idx, topic in enumerate(model.components_):                                                                                                             
        print(f"Topic {topic_idx}:")
        print(" ".join([features[i]
                        for i in topic.argsort()[:-no_top_words-1:-1]])) # syntax for reversing a list [::-1]

display_topics(lda, feature_names, 30)
# Out:
# Topic 0:
# makeup christmas skin beauty grwm day skincare tutorial tree gift face foundation make michael eye products blush look sabrina routine carpenter card haul sephora concealer victoria ready chipotle san care
# Topic 1:
# new nyc york apartment mom interview history life dating work city link bio park south questions corporate job lana relationship mexico john time got coquette street subway funny year living
# Topic 2:
# recipe food chicken recipes cheese girls birthday mean make free dinner cake cooking rice cup pasta cream ideas add meal oil easy making thanksgiving milk chocolate pepper bell salad butter
# Topic 3:
# hair disney water girl black white soup mascara brown game cut haircut crochet blue brush color accent stanley fnaf hairstyles teeth curly glass mexican twilight hairstyle cup bangs lunch tutorial
# Topic 4:
# lip funny olivia cleaning bachelor rodrigo williams doctorwho snl wendy prank joey love comedy family trump moments davidtennant balm shoes videos edit perfume lips clean shane summer emma gloss maria
# Topic 5:
# avatar dance home parents candy smith nails princess mac apple airbender iphone rachel zuko proposal bathroom podcast marriage tea live girl action cookie alex nail bear dancing kitchen kids board
# Topic 6:
# college school student doctor life university taylorswift ice dad david tennant money swifttok science football swiftie medical major high tiktok musical law students singing harvard basketball theatre song engineering med
# Topic 7:
# like just know think good little love don dont time people dune way life replying sister year did feel let want really brother say big right hard look family got
# Topic 8:
# taylor swift stitch song music super songs golden tour travis bowl austin eras kelce usher grammys hamilton love justin lyrics concert globes acne guitar jennifer black jacob beyonce singing bella
# Topic 9:
# food dress outfits outfit tiktok teacher couple fashion room couples ideas target african clothes videos spanish language dresses ootd fall life style french pregnant speaking orange sydney hamster english clothing
# Topic 10:
# book joe things books replying starbucks korean booktok pizza noah kim greenscreen indian mitski miami therapy song tiktok trader tattoo kpop bts poetry poor pants saltburn guess roommate scott graduation
# Topic 11:
# cat baby wedding videos cats tiktok games cute funny barbie hunger date snow art jeans animals josh tom pet zendaya painting drake edit twins animal gray kittens catsoftiktok lucy old
# Topic 12:
# movie car house harry travel scene timothee beyonce body long love movies chalamet potter kylie time chicago shop film wonka fish tiktok wig ending sza scary ocean family horror garden
# Topic 13:
# love boston halloween costume jackson thrift nicki blind percy minaj ariana megan thrifting grande anime ring haul spongebob stallion kpop thee gym fortnite gojo store finds massachusetts sarah elementary empire
# Topic 14:
# dog filter bag dogs coffee face tiktok office green eyes business lee tote videos deodorant puppy effect funny grey anatomy cake test black bags google keith shop phone coach dogsoftiktok

# %%
def displayHeader(model, features, no_top_words):
    """Helper function to show the top words of a model"""
    topicNames = []
    for topic_idx, topic in enumerate(model.components_):
        topicNames.append(f"Topic {topic_idx}: " + (", ".join([features[i]
                             for i in topic.argsort()[:-no_top_words-1:-1]])))
    return topicNames

# %%
# column names
topicnames = displayHeader(lda, feature_names, 0)

# index names
docnames = allDocs.index.tolist() # We will use the original names of the documents

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(doc_topic_dist, 3), 
                                 columns=topicnames, 
                                 index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1) # finds the maximum argument
df_document_topic['dominant_topic'] = dominant_topic

df_document_topic.tail()
# Out:
#         Topic 0:   Topic 1:   Topic 2:   Topic 3:   Topic 4:   Topic 5:   \
# user10      0.814      0.002      0.002      0.002      0.002      0.002
# user10      0.004      0.004      0.004      0.609      0.004      0.004
# user10      0.003      0.003      0.003      0.003      0.003      0.003
# user10      0.299      0.002      0.002      0.002      0.002      0.002
# user10      0.003      0.003      0.003      0.003      0.003      0.003
#
#         Topic 6:   Topic 7:   Topic 8:   Topic 9:   Topic 10:   Topic 11:   \
# user10      0.002      0.054      0.105      0.002       0.002       0.002
# user10      0.004      0.004      0.004      0.004       0.004       0.345
# user10      0.003      0.003      0.003      0.003       0.066       0.768
# user10      0.002      0.163      0.459      0.052       0.002       0.002
# user10      0.003      0.003      0.353      0.003       0.497       0.003
#
#         Topic 12:   Topic 13:   Topic 14:   dominant_topic
# user10       0.002       0.002       0.002               0
# user10       0.004       0.004       0.004               3
# user10       0.003       0.128       0.003              11
# user10       0.002       0.002       0.002               8
# user10       0.003       0.003       0.110              10

# %%
df_document_topic = df_document_topic.reset_index()
df_document_topic = df_document_topic.drop(columns = ['dominant_topic'])
df_document_topic.head()
# Out:
#    index  Topic 0:   Topic 1:   Topic 2:   Topic 3:   Topic 4:   Topic 5:   \
# 0  user1      0.153      0.003      0.208      0.003      0.003      0.003
# 1  user1      0.007      0.149      0.338      0.007      0.007      0.007
# 2  user1      0.010      0.241      0.010      0.010      0.010      0.010
# 3  user1      0.007      0.007      0.007      0.007      0.007      0.007
# 4  user1      0.011      0.011      0.011      0.367      0.011      0.011
#
#    Topic 6:   Topic 7:   Topic 8:   Topic 9:   Topic 10:   Topic 11:   \
# 0      0.003      0.323      0.003      0.115       0.003       0.003
# 1      0.007      0.007      0.007      0.424       0.007       0.007
# 2      0.010      0.010      0.010      0.010       0.133       0.010
# 3      0.007      0.007      0.007      0.007       0.007       0.007
# 4      0.011      0.489      0.011      0.011       0.011       0.011
#
#    Topic 12:   Topic 13:   Topic 14:
# 0       0.171       0.003       0.003
# 1       0.007       0.007       0.007
# 2       0.512       0.010       0.010
# 3       0.896       0.007       0.007
# 4       0.011       0.011       0.011

# %%
grouped = df_document_topic.groupby('index')

# %%
averages = grouped.mean()
averages
# Out:
#         Topic 0:   Topic 1:   Topic 2:   Topic 3:   Topic 4:   Topic 5:   \
# index
# user1    0.044873   0.055535   0.061423   0.094662   0.066437   0.050901
# user10   0.085492   0.054340   0.084519   0.044227   0.045364   0.044393
# user2    0.047825   0.073035   0.047961   0.058706   0.064430   0.061708
# user3    0.047864   0.077558   0.050470   0.048451   0.086165   0.050500
# user4    0.053902   0.068135   0.045288   0.046029   0.074939   0.072143
# user5    0.062856   0.067138   0.070451   0.053860   0.056653   0.052149
# user6    0.008824   0.054941   0.030471   0.057500   0.104971   0.090912
# user7    0.070583   0.065751   0.100826   0.059780   0.049475   0.050452
# user8    0.050287   0.062983   0.063597   0.053399   0.050525   0.048734
# user9    0.063263   0.052681   0.051590   0.063222   0.056718   0.050091
#
#         Topic 6:   Topic 7:   Topic 8:   Topic 9:   Topic 10:   Topic 11:   \
# index
# user1    0.060070   0.109085   0.030028   0.067901    0.064352    0.029732
# user10   0.065901   0.134765   0.081481   0.066981    0.082425    0.038096
# user2    0.088714   0.134022   0.065158   0.074635    0.063873    0.064847
# user3    0.069315   0.143453   0.070319   0.052024    0.064077    0.065064
# user4    0.093863   0.134255   0.052251   0.059484    0.057739    0.052317
# user5    0.069034   0.144497   0.067464   0.064974    0.078376    0.057593
# user6    0.023941   0.199971   0.064971   0.022824    0.080529    0.054824
# user7    0.048241   0.145357   0.050612   0.073571    0.053336    0.055459
# user8    0.088609   0.176074   0.060387   0.049725    0.069157    0.053645
# user9    0.052348   0.143980   0.047530   0.053474    0.082527    0.058962
#
#         Topic 12:   Topic 13:   Topic 14:
# index
# user1     0.175592    0.022690    0.066099
# user10    0.049382    0.060262    0.062484
# user2     0.055911    0.045906    0.053190
# user3     0.058684    0.065164    0.050721
# user4     0.070509    0.063459    0.055558
# user5     0.054877    0.048489    0.051358
# user6     0.118324    0.067941    0.018559
# user7     0.055761    0.065184    0.055456
# user8     0.059346    0.055468    0.057832
# user9     0.059940    0.103470    0.060088

# %%
# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(averages, cmap="YlGnBu", fmt="d")
plt.title('Heatmap of User-Topic Probabilities')
plt.xlabel('Topics')
plt.ylabel('Users')
plt.yticks(rotation=0)
plt.show()

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Sentences']
df_topic_distribution
# Out:
#     Topic Num  Num Sentences
# 0           7          13978
# 1           6           5531
# 2           1           5475
# 3           2           5394
# 4          10           5310
# 5          13           5294
# 6           0           5197
# 7           4           5170
# 8           9           4586
# 9          12           4483
# 10          8           4458
# 11         11           4370
# 12          3           4187
# 13         14           4039
# 14          5           3994

# %%
# Extract data from DataFrame columns
x_values = df_topic_distribution['Topic Num']
y_values = df_topic_distribution['Num Sentences']

# Plot the bar chart
plt.style.use('ggplot')
plt.figure(figsize = (20, 10))
plt.bar(x_values, y_values)

# Add labels and title
plt.xlabel('Topics')
plt.ylabel('Sentence Counts')
plt.title('Bar Chart of Topics vs. Sentences (All Users)')

# Rotate x-axis labels for better readability (if needed)
plt.xticks(rotation=45)

## Add percentages to the bars
# Calculate percentages
total = sum(y_values)
percentages = [(value / total) * 100 for value in y_values]

#for i, percentage in enumerate(percentages):
 #   plt.text(i, y_values[i] + 0.5, f'{percentage:.2f}%', ha='center', va='bottom', rotation=45, fontsize=8)

# Annotate bars with percentages
for i, (x, y) in enumerate(zip(x_values, y_values)):
    plt.text(i, y + 0.5, f'{percentages[i]:.1f}%', ha='center')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate percentages
total = sum(values)
percentages = [(value / total) * 100 for value in values]

# Plotting the bar chart
plt.bar(categories, values, color='skyblue')

# Annotate bars with percentages
for i, percentage in enumerate(percentages):
    plt.text(i, values[i] + 0.5, f'{percentage:.1f}%', ha='center')

# %%
# Assuming 'df' is your DataFrame
df_document_topic.reset_index(inplace=True)
df_document_topic
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nd/my_j6y6s0p544s5nzvtvnntm0000gn/T/ipykernel_79857/1169078972.py in ?()
#       1 # Assuming 'df' is your DataFrame
# ----> 2 df_document_topic.reset_index(inplace=True)
#       3 df_document_topic
#
# ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6455                     level_values = algorithms.take(
#    6456                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6457                     )
#    6458
# -> 6459                 new_obj.insert(
#    6460                     0,
#    6461                     name,
#    6462                     level_values,
#
# ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5141                 "'self.flags.allows_duplicate_labels' is False."
#    5142             )
#    5143         if not allow_duplicates and column in self.columns:
#    5144             # Should this be a different kind of error??
# -> 5145             raise ValueError(f"cannot insert {column}, already exists")
#    5146         if not is_integer(loc):
#    5147             raise TypeError("loc must be int")
#    5148         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert level_0, already exists

# %%
# Extract data from DataFrame columns
x_values = df_document_topic['index']
y_values = df_document_topic['dominant_topic']

# Plot the bar chart
plt.bar(x_values, y_values)

# Add labels and title
plt.xlabel('Topics')
plt.ylabel('Video Counts')
plt.title('Bar Chart of Topics vs. Videos')

# Rotate x-axis labels for better readability (if needed)
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Find the most frequent dominant_topic per user
most_frequent_topics = df_document_topic.groupby('index')['dominant_topic'].apply(lambda x: x.mode().iloc[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Find the most frequent dominant_topic per user
# ----> 2 most_frequent_topics = df_document_topic.groupby('index')['dominant_topic'].apply(lambda x: x.mode().iloc[0])
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: dominant_topic'

# %%
# Find the most frequent dominant_topic per user
most_frequent_topics = df_document_topic.groupby('index')['dominant_topic'].apply(lambda x: x.value_counts().idxmax())

# Print the result
most_frequent_topics
# Out:
# index
# user1     12
# user10     7
# user2      7
# user3      7
# user4      7
# user5      7
# user6      7
# user7      7
# user8      7
# user9      7
# Name: dominant_topic, dtype: int64
